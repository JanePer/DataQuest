# %% [markdown]
# # Visualizing The Gender Gap In College Degrees

# %% [markdown]
# ## STEM categories ordered by decreasing of ending gender gap

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt

women_degrees = pd.read_csv('percent-bachelors-degrees-women-usa.csv')
cb_dark_blue = (0/255,107/255,164/255)
cb_orange = (255/255, 128/255, 14/255)
stem_cats = ['Engineering', 'Computer Science', 'Psychology', 'Biology', 'Physical Sciences', 'Math and Statistics']

fig = plt.figure(figsize=(21, 3))

for sp in range(0,6):
    ax = fig.add_subplot(1,6,sp+1)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    
    if sp == 0:
        ax.text(2005, 87, 'Men')
        ax.text(2002, 8, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men')
        ax.text(2001, 35, 'Women')
plt.show()

# %% [markdown]
# ## All degree categories ordered in descending order by the percentage of degrees awarded to women
#
# We grouped all degree categories into 3 groups:
# - **STEM**: Psychology, Biology, Math and Statistics, Physical Sciences, Computer Science, Engineering
# - **Liberal arts**: Foreign Languages, English, Communications and Journalism, Art and Performance, Social Sciences and History
# - **Others**: Health Professions, Public Administration, Education, Agriculture, Business, Architecture
#
# To generate line charts we'll use a subplot grid layout of 6 rows by 3 columns, where
# - STEM group is in the first column
# - Liberal arts - in the second column
# - Others are in the third column
#
# Categories of each group are ordered in descending order by the percentage of degrees awarded to women.

# %%
stem_cats = ['Psychology', 'Biology', 'Math and Statistics', 'Physical Sciences', 'Computer Science', 'Engineering']
lib_arts_cats = ['Foreign Languages', 'English', 'Communications and Journalism', 'Art and Performance', 'Social Sciences and History']
other_cats = ['Health Professions', 'Public Administration', 'Education', 'Agriculture','Business', 'Architecture']

fig = plt.figure(figsize=(16, 16))
sp=0
range1=[1,4,7,10,13,16]
for r in range1:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 80, 'Women')
    elif sp == 5:
        ax.text(2005, 90, 'Men') 
        ax.text(2001, 8, 'Women')
    sp=sp+1


sp=0
range2=[2,5,8,11,14]
for r in range2:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 75, 'Women')
    sp=sp+1


sp=0
range3=[3,6,9,12,15,18]
for r in range3:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False)
    if sp == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 90, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men') 
        ax.text(2002, 35, 'Women')
    sp=sp+1
plt.show()

# %% [markdown]
# ## Hiding x-axis labels

# %% [markdown]
# With seventeen line charts in one diagram, the non-data elements quickly clutter the field of view. The titles of some line charts may overlapp with the x-axis labels for the line chart above it. To avoid this we will disable the x-axis labels for all of the line charts except the bottommost line charts in each column.

# %%
fig = plt.figure(figsize=(16, 16))
sp=0
range1=[1,4,7,10,13,16]
for r in range1:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 80, 'Women')
    elif sp == 5:
        ax.text(2005, 90, 'Men') 
        ax.text(2001, 8, 'Women')
        ax.tick_params(labelbottom="on")
    sp=sp+1


sp=0
range2=[2,5,8,11,14]
for r in range2:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 75, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
    sp=sp+1


sp=0
range3=[3,6,9,12,15,18]
for r in range3:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 90, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men') 
        ax.text(2002, 35, 'Women')
        ax.tick_params(labelbottom='on')
    sp=sp+1
plt.show()

# %% [markdown]
# ## Setting y-axis labels

# %% [markdown]
# In the vein of reducing cluttering, let's also simplify the y-axis labels. Currently, all seventeen plots have six y-axis labels. By keeping just the starting and ending labels (0 and 100), we can keep some of the benefits of having the y-axis labels to begin with.

# %%
fig = plt.figure(figsize=(16, 16))
sp=0
range1=[1,4,7,10,13,16]
for r in range1:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.set_yticks([0,100])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 80, 'Women')
    elif sp == 5:
        ax.text(2005, 90, 'Men') 
        ax.text(2001, 8, 'Women')
        ax.tick_params(labelbottom='on')
    
    sp=sp+1


sp=0
range2=[2,5,8,11,14]
for r in range2:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 75, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
    sp=sp+1


sp=0
range3=[3,6,9,12,15,18]
for r in range3:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 90, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men') 
        ax.text(2002, 35, 'Women')
        ax.tick_params(labelbottom='on')
    sp=sp+1
plt.show()

# %% [markdown]
# ## Adding a horizontal line

# %% [markdown]
# Removing most of the y-axis labels definitely reduced clutter, but it also made it hard to understand which degrees have close to 50-50 gender breakdown. That's why we will use a horizontal line across all of the line charts where the y-axis label 50 would have been.
#
# We will use light gray color in the [Color Blind 10 palette](http://tableaufriction.blogspot.com/2012/11/finally-you-can-use-tableau-data-colors.html) and the transparency using the alpha parameter.

# %%
fig = plt.figure(figsize=(16, 16))
sp=0
range1=[1,4,7,10,13,16]
for r in range1:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 80, 'Women')
    elif sp == 5:
        ax.text(2005, 90, 'Men') 
        ax.text(2001, 8, 'Women')
        ax.tick_params(labelbottom='on')
    sp=sp+1


sp=0
range2=[2,5,8,11,14]
for r in range2:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 75, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
    sp=sp+1


sp=0
range3=[3,6,9,12,15,18]
for r in range3:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    ax.set_title(other_cats[sp])
    if sp == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 90, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men') 
        ax.text(2002, 35, 'Women')
        ax.tick_params(labelbottom='on')
    sp=sp+1
plt.show()

# %% [markdown]
# ## Exporting to a file

# %%
fig = plt.figure(figsize=(16, 16))
sp=0
range1=[1,4,7,10,13,16]
for r in range1:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[stem_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[stem_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_title(stem_cats[sp])
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 80, 'Women')
    elif sp == 5:
        ax.text(2005, 90, 'Men') 
        ax.text(2001, 8, 'Women')
        ax.tick_params(labelbottom='on')
    sp=sp+1


sp=0
range2=[2,5,8,11,14]
for r in range2:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[lib_arts_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[lib_arts_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.set_title(lib_arts_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 15, 'Men')
        ax.text(2002, 75, 'Women')
    if sp == 4:
        ax.tick_params(labelbottom='on')
    sp=sp+1


sp=0
range3=[3,6,9,12,15,18]
for r in range3:
    ax = fig.add_subplot(6,3,r)
    ax.plot(women_degrees['Year'], women_degrees[other_cats[sp]], c=cb_dark_blue, label='Women', linewidth=3)
    ax.plot(women_degrees['Year'], 100-women_degrees[other_cats[sp]], c=cb_orange, label='Men', linewidth=3)
    ax.spines["right"].set_visible(False)    
    ax.spines["left"].set_visible(False)
    ax.spines["top"].set_visible(False)    
    ax.spines["bottom"].set_visible(False)
    ax.set_xlim(1968, 2011)
    ax.set_ylim(0,100)
    ax.set_yticks([0,100])
    ax.axhline(50, c=(171/255, 171/255, 171/255), alpha=0.3)
    ax.set_title(other_cats[sp])
    ax.tick_params(bottom=False, top=False, left=False, right=False, labelbottom=False)
    if sp == 0:
        ax.text(2005, 8, 'Men')
        ax.text(2002, 90, 'Women')
    elif sp == 5:
        ax.text(2005, 62, 'Men') 
        ax.text(2002, 35, 'Women')
        ax.tick_params(labelbottom='on')
    sp=sp+1

fig.savefig("gender_degrees.png")    
plt.show()
